# %%
'''
Question 1
When you run the code, there will be a SyntaxError first, remove the error.'''

# my_string = input("Type a string: ")
# letternumber = 1
# for letter in my_string:
#      print("Letter", letternumber, "is", letter)
#      letternumber += 1

#===================================================================
#===================================================================

'''Question 2
A TypeError will be received after the SyntaxError resolves, resolve the error.
'''
# my_string = input("Type a string: ")
# letternumber = 1
# for letter in my_string:
#      print("Letter", letternumber, "is", letter)
#      letternumber += 1

#===================================================================
#===================================================================

'''Question 3
Eliminate NameError.
'''

# writer = {
#      "Fullname": "Victor Hugo",
#      "Country": "France",
#      "Book": "Les Misérables",
#      "Year": 1862
# }
# print(writer.get("Book"))

#===================================================================
#===================================================================

'''Question 4
Eliminate KeyError.

'''
# movie_info = {
#      "Movie": "Judgment at Nuremberg",
#      "Director": "Stanley Kramer",
#      "Country": "United States",
#      "Year": 1961,
#      "Languages": "English, German"
# }
# movie_info["Year"]


#===================================================================
#===================================================================

'''Question 5
Remove the error.

'''

# def writers_books(**kwargs):
#     print(" ")

#     for key, value in kwargs.items():
#         print("{} is {}".format(key, value))
  
# writers_books(Firstname = "Victor", Lastname = "Hugo", Birthdate = "02.26.1802", 
#               Deathdate = "05.22.1885", Country = "France", Book = "Les Misérables", Year = 1862)
# writers_books(Firstname = "Fyodor", Lastname = "Dostoevsky", Birthdate = "11.11.1821", 
#               Deathdate = "02.09.1881", Country = "Russia", Book = "Crime and Punishment", Year = 1866)
# writers_books(Firstname = "Umberto", Lastname = "Eco", Birthdate = "01.05.1932", 
#               Deathdate = "02.19.2016", Country = "Italy", Book = "The Name of the Rose", Year = 1980)

#===================================================================
#===================================================================

'''Question 6
In the continuation of the code below, add 2 except blocks.
In the 1st except block, NameError, in the print part, "a is not defined, you cannot print it.",
In the print part of the 2nd except block, "There is another wrong." be written.

'''
# a = 5
# try:
#      print(a)
# except:
#      print("Incompleted")



#===================================================================
#===================================================================

'''Question 7
In the continuation of the code below, add an except, and a finally block.
In the except block, ZeroDivisionError, in the print part, ""There is ZeroDivisionError:", ZeroDivisionError",
In the print part of the Finally block, "That's all." let it be
Finally, call the function and run it.

'''

# def divide_numbers_1(a, b):

#     try:
#          print(a / b)
#     except ZeroDivisionError as e:
#          print(f"There is ZeroDivisionError: {e}")
#     finally:
#          print("That's all. block completed")

# divide_numbers_1(15,0)


#===================================================================
#===================================================================

'''Question 8
In the continuation of the code, add an except block, 
in the print part "There is a name error." type and then add a raise block.
'''
# a = "Python"
# try:
#      raise NameError(a)
# except NameError:
#      print("There is a name error.")


#===================================================================
#===================================================================

'''Question 9
Read the first 11 letters of the file named my_file1.
'''
# reader = open("my_file1.txt")
# reader.read(11)


#===================================================================
#===================================================================

'''Question 10
to a file named my_file2
"This versatility, along with its beginner-friendliness, has made it one of the most-used programming languages today."
add this sentence."


'''
# str = "This versatility, along with its beginner-friendliness, has made it one of the most-used programming languages today."

# with open("my_file2.txt", "a") as writer:
#     writer.write(str)
# Out:
#   Cell In[11], line 91
#
#     ^
# SyntaxError: incomplete input
